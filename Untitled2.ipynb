# %%
import sys
sys.path.append('/home/sapje1/code/twixtools')
import twixtools
import os

# %%
data_dir = '/home/sapje1/data_sapje1/projects/mrs_thalamus'
data_file = 'meas_MID91_sLaser_Brainstem_20_12_12_FID121173.dat'

# %%
full_path = os.path.join(data_dir,data_file)

# %%
twix_in = twixtools.read_twix(full_path)
# Out:
# in read_twix
# Software  : VB (!?)
# [0] [74274976]
#
# Im in parse_twix_hdr
# len(tmp)
# 48
# tmp
# b'Config\x00\x1c}\x01\x00<XProtocol> \n{\n  \n  <ParamMap.""> \n  '
# pattern
# b'(\\w{4,})\\x00(.{4})'
# <re.Match object; span=(0, 11), match=b'Config\x00\x1c}\x01\x00'>
# len(tmp)
# 48
# tmp
# b'Dicom\x00\xdd\x10\x00\x00<XProtocol> \n{\n  \n  <ParamMap.""> \n  {'
# pattern
# b'(\\w{4,})\\x00(.{4})'
# <re.Match object; span=(0, 10), match=b'Dicom\x00\xdd\x10\x00\x00'>
# len(tmp)
# 48
# tmp
# b'Meas\x00\xfe\xd6\x05\x00<XProtocol> \n{\n  <Name> "ONLINE Pipe Co'
# pattern
# b'(\\w{4,})\\x00(.{4})'
# <re.Match object; span=(0, 9), match=b'Meas\x00\xfe\xd6\x05\x00'>
# len(tmp)
# 48
# tmp
# b'MeasYaps\x00zv\x00\x00### ASCCONV BEGIN ###\nulVersion    '
# pattern
# b'(\\w{4,})\\x00(.{4})'
# <re.Match object; span=(0, 13), match=b'MeasYaps\x00zv\x00\x00'>
# len(tmp)
# 48
# tmp
# b'Phoenix\x00Z\xd8\x00\x00<XProtocol> \n{\n  <Name> "MultiStep C'
# pattern
# b'(\\w{4,})\\x00(.{4})'
# ...

# %%
print(twix_in[0])
# Out:
# {'mdb': [<twixtools.mdb.Mdb object at 0x7f60b6e91bb0>, <twixtools.mdb.Mdb object at 0x7f60b77035b0>, <twixtools.mdb.Mdb object at 0x7f60b6e91880>, <twixtools.mdb.Mdb object at 0x7f60b7705640>, <twixtools.mdb.Mdb object at 0x7f60b6e91c70>, <twixtools.mdb.Mdb object at 0x7f60b77a8730>, <twixtools.mdb.Mdb object at 0x7f61085007f0>, <twixtools.mdb.Mdb object at 0x7f60b7705be0>, <twixtools.mdb.Mdb object at 0x7f60b77a8670>, <twixtools.mdb.Mdb object at 0x7f60b79098e0>, <twixtools.mdb.Mdb object at 0x7f60b6e91eb0>, <twixtools.mdb.Mdb object at 0x7f60b77a8c40>, <twixtools.mdb.Mdb object at 0x7f60b76d0520>, <twixtools.mdb.Mdb object at 0x7f60b6e919d0>, <twixtools.mdb.Mdb object at 0x7f60b79091c0>, <twixtools.mdb.Mdb object at 0x7f60b6e91670>, <twixtools.mdb.Mdb object at 0x7f60b6e91730>, <twixtools.mdb.Mdb object at 0x7f60b76d0460>, <twixtools.mdb.Mdb object at 0x7f60b76d0610>, <twixtools.mdb.Mdb object at 0x7f60b7909340>, <twixtools.mdb.Mdb object at 0x7f60b76d0d60>, <twixtools.mdb.Mdb obje
# ...

# %%
help(twixtools.mdb)
# Out:
# Help on module twixtools.mdb in twixtools:
#
# NAME
#     twixtools.mdb
#
# CLASSES
#     builtins.object
#         Mdb_base
#             Mdb
#             Mdb_local
#
#     class Mdb(Mdb_base)
#      |  Mdb(fid=None, version_is_ve=True)
#      |
#      |  Memory-mapped storage class for Siemens MRI raw data.
#      |
#      |  The function `read_twix` parses the twix file and stores all
#      |  information (such as counters as well as the position of the data
#      |  within the twix file) in a list of Mdb objects.
#      |
#      |  Important Attributes
#      |  ----------
#      |  data: This will read the data from disk and return a 2D numpy
#      |        array (channels x columns).
#      |  mdh: measurement data header, stored as a special numpy.dtype.
#      |       You can get information about the order of the stored
#      |       information (counters and such) with `print(mdh.dtype)`.
#      |
#      |  Important Methods
#      |  ----------
# ...

# %%
print(twix_in[0]['mdb'][1].data.shape)
# Out:
# (32, 4096)

# %%
len(twix_in[0]['mdb'])
# Out:
# 70
